# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_movies = pd.read_csv("tmdb-movies.csv")

# %%
df_movies.shape
# Out:
# (10866, 21)

# %%
df_movies.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
sum(df_movies['genres'].isnull())
# Out:
# 23

# %%
genre = df_movies['genres'].str.split('|').apply(pd.Series)
genre.rename(columns =lambda x: 'genre_' +str(x), inplace=True)
dfx = pd.concat([df_movies,genre], axis=1, sort=False)

# %% [markdown]
# # Genres Trend Analysis

# %%
plt.figure(figsize=(25, 8))
plt.bar(dfx.groupby('genre_0').count()['id'].sort_values(ascending=False).index, dfx.groupby('genre_0').count()['id'].sort_values(ascending=False) )
plt.ylabel('Movie Count')
plt.xlabel('Genres')
plt.title('Overall Genre Trend over 55 Years')
# Out:
# Text(0.5, 1.0, 'Overall Genre Trend over 55 Years')

# %%
plt.figure(figsize=(25, 8))
plt.bar(dfx.groupby('genre_0').count()['id'].sort_values(ascending=False).index, dfx.groupby('genre_0').count()['id'].sort_values(ascending=False) )
plt.ylabel('Movie Count')
plt.xlabel('Genres')
plt.title('Overall Genre Trend over 55 Years')
# Out:
# Text(0.5, 1.0, 'Overall Genre Trend over 55 Years')

# %%
def plot_genre(df , st_yr, end_yr):
    df_temp= df[((df['release_year']>=st_yr)& (df['release_year']<=end_yr))]
    plt.figure(figsize=(25, 8))
    plt.bar(df_temp.groupby('genre_0').count()['id'].sort_values(ascending=False).index, df_temp.groupby('genre_0').count()['id'].sort_values(ascending=False) )
    plt.ylabel('Movie Count')
    plt.xlabel('Genres')
    plt.title('Overall Genre Trend Between{} and {}.'.format(st_yr, end_yr))

# %%
plot_genre(dfx, 2010, 2015)

# %%
plot_genre(dfx, 2005, 2010)

# %%
plot_genre(dfx, 2000, 2005)

# %%
plot_genre(dfx, 1995, 2000)

# %%
plot_genre(dfx, 1990, 1995)

# %%
plot_genre(dfx, 1985, 1990)

# %%
plot_genre(dfx, 1980, 1985)

# %%
plot_genre(dfx, 1975, 1980)

# %%
plot_genre(dfx, 1970, 1975)

# %%
plot_genre(dfx, 1965, 1970)

# %%
plot_genre(dfx, 1960, 1965)

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
# id                      10866 non-null int64
# imdb_id                 10856 non-null object
# popularity              10866 non-null float64
# budget                  10866 non-null int64
# revenue                 10866 non-null int64
# original_title          10866 non-null object
# cast                    10790 non-null object
# homepage                2936 non-null object
# director                10822 non-null object
# tagline                 8042 non-null object
# keywords                9373 non-null object
# overview                10862 non-null object
# runtime                 10866 non-null int64
# genres                  10843 non-null object
# production_companies    9836 non-null object
# release_date            10866 non-null object
# vote_count              10866 non-null int64
# vote_average            10866 non-null float64
# ...

# %%
df_movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df_movies.shape
# Out:
# (10866, 21)

# %%
sum(df_movies.isnull().any())
# Out:
# 9

# %%
df_credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
df_credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
df_credits.shape
# Out:
# (4803, 4)

# %%
df_5000_movies = pd.read_csv('tmdb_5000_movies.csv')

# %%
df_5000_movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df_5000_movies.shape
# Out:
# (4803, 20)

# %%
df_5000_movies.shape
# Out:
# (4803, 20)

# %%
df_movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
#(df_movies['genres'].str.split('|')[0]).dtypes

df_movies['genres']=df_movies['genres'].fillna('A')
sum(df_movies['genres'].isnull())
# Out:
# 0

# %%
sum(df_movies['cast'].isnull())
# Out:
# 76

# %%
df_movies['cast'].fillna('C' , inplace=True)

# %%
sum(df_movies['budget'].isnull())
# Out:
# 0

# %%
sum(df_movies['revenue'].isnull())
# Out:
# 0

# %%
df_non_zero_budget = df_movies[df_movies['budget']!=0]

# %%
df_non_zero_budget.shape
# Out:
# (5170, 21)

# %%
df_non_zero_revenue = df_movies[df_movies['revenue']!=0]

# %%
df_non_zero_revenue.shape
# Out:
# (4850, 21)

# %%
df_non_zero_revenue_budget = df_non_zero_budget[df_non_zero_budget['revenue']!=0 ]
df_sorted = df_non_zero_revenue_budget.sort_values(by=['revenue'], ascending=False)
df_sorted.head(100)
# Out:
#           id    imdb_id  popularity     budget     revenue  \
# 1386   19995  tt0499549    9.432768  237000000  2781505847
# 3     140607  tt2488496   11.173104  200000000  2068178225
# 5231     597  tt0120338    4.355219  200000000  1845034188
# 4361   24428  tt0848228    7.637767  220000000  1519557910
# 0     135397  tt0369610   32.985763  150000000  1513528810
# 4     168259  tt2820852    9.335014  190000000  1506249360
# 14     99861  tt2395427    5.944927  280000000  1405035767
# 3374   12445  tt1201607    5.711315  125000000  1327817822
# 5422  109445  tt2294629    6.112766  150000000  1274219009
# 5425   68721  tt1300854    4.946136  200000000  1215439994
# 8     211672  tt2293640    7.404165   74000000  1156730962
# 3522   38356  tt1399103    0.760503  195000000  1123746996
# 4949     122  tt0167260    7.122455   94000000  1118888979
# 4365   37724  tt1074638    5.603587  200000000  1108561013
# 8094    1642  tt0113957    1.136610   22000000  1106279658
# ...

# %%
df_sorted['profit'] = df_sorted['revenue'] - df_sorted['budget']

# %%
df_movies.head(1)
# Out:
#        id    imdb_id  popularity     budget     revenue  original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
#
#                         homepage         director            tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow  The park is open.  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
#
# [1 rows x 21 columns]

# %%
sum(df_movies['popularity'].isnull())
# Out:
# 0

# %% [markdown]
# ### Finding
# in movies dataset 'revenue_adj' and budget_adj are not null
# However revenue and budget columns are null more than 50%
# Conclusion: remove revenue and budget columns use 'revenue_adj' and budget_adj columns for analysis

# %%
df_movies['popularity'].min()
# Out:
# 6.500000000000001e-05

# %%
df_movies['popularity'].quantile(.99)
# Out:
# 4.581144100000003

# %%
plt.boxplot(df_movies['revenue_adj'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16159dfd320>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16159dfd9b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16159e14ef0>],
#  'medians': [<matplotlib.lines.Line2D at 0x16159dfddd8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16159dfbc18>],
#  'means': []}

# %% [markdown]
# ##### Data Description
# This data set contains information
# about 10,000 movies collected from
# The Movie Database (TMDb),
# including user ratings and revenue.
# ● Certain columns, like ‘cast’
# and ‘genres’, contain multiple
# values separated by pipe (|)
# characters.
# ● There are some odd characters
# in the ‘cast’ column. Don’t worry
# about cleaning them. You can
# leave them as is.
# ● The final two columns ending
# with “_adj” show the budget and
# revenue of the associated movie
# in terms of 2010 dollars,
# accounting for inflation over
# time.

# %% [markdown]
# ##### Potential Question 1:
#
# Which genres are most popular from year to year?

# %% [markdown]
# ##### Potential Question 2:
#
# What kinds of properties are associated with movies that have high revenues?

# %%
df_movies.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
df_movies['budget_adj'].isnull().any()
# Out:
# False

# %%
df_movies['budget_adj'].quantile(.5)
# Out:
# 0.0

# %%
df1 = df_movies[df_movies['budget_adj']!=0.0]
df1.shape
# Out:
# (5170, 21)

# %%
df2 = df_movies[df_movies['revenue_adj']!=0.0]
df2.shape
# Out:
# (4850, 21)

# %% [markdown]
# # df3 contains no zero values of adjusted budget and revenue values

# %%
df3 = df2[df2["budget_adj"]!=0]
df3.shape
# Out:
# (3855, 21)

# %%
df3.describe()
# Out:
#                   id   popularity        budget       revenue      runtime  \
# count    3855.000000  3855.000000  3.855000e+03  3.855000e+03  3855.000000
# mean    39888.783398     1.191400  3.720183e+07  1.076589e+08   109.215824
# std     67213.815955     1.475002  4.220291e+07  1.765248e+08    19.922166
# min         5.000000     0.001117  1.000000e+00  2.000000e+00    15.000000
# 25%      6074.000000     0.462448  1.000000e+07  1.357645e+07    95.000000
# 50%     11322.000000     0.797298  2.400000e+07  4.479322e+07   106.000000
# 75%     38577.000000     1.368245  5.000000e+07  1.241530e+08   119.000000
# max    417859.000000    32.985763  4.250000e+08  2.781506e+09   338.000000
#
#         vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  3855.000000    3855.00000   3855.000000  3.855000e+03  3.855000e+03
# mean    527.611933       6.16786   2001.263294  4.423630e+07  1.370294e+08
# ...

# %%
df3.describe()['revenue_adj']
# Out:
# count    3.855000e+03
# mean     1.370294e+08
# std      2.160944e+08
# min      2.370705e+00
# 25%      1.834123e+07
# 50%      6.171861e+07
# 75%      1.632401e+08
# max      2.827124e+09
# Name: revenue_adj, dtype: float64

# %%
plt.boxplot(df3['revenue_adj'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16159394550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16159394be0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16159394160>],
#  'medians': [<matplotlib.lines.Line2D at 0x161593882b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x161593885f8>],
#  'means': []}

# %%
df3['profit'] = df3['revenue_adj'] - df3['budget_adj']
# Out:
# C:\Users\asimn\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df3['%profit'] = df3['profit'] /df3['budget_adj']
# Out:
# C:\Users\asimn\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df3['budget_adj'].corr(df3['revenue_adj'])
# Out:
# 0.570466122118637

# %%
df3['vote_average'].corr(df3['revenue_adj'])
# Out:
# 0.2669960847487646

# %%
df3['runtime'].corr(df3['revenue_adj'])
# Out:
# 0.2806043799668933

# %%
df3['popularity'].corr(df3['revenue_adj'])
# Out:
# 0.5469854133800129

# %%
df3.head(1)
# Out:
#        id    imdb_id  popularity     budget     revenue  original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
#
#                         homepage         director            tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow  The park is open.  ...
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies  release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...        6/9/15       5562
#
#   vote_average release_year    budget_adj   revenue_adj        profit  \
# 0          6.5         2015  1.379999e+08  1.392446e+09  1.254446e+09
#
#     %profit
# 0  9.090192
#
# [1 rows x 23 columns]

# %%
df3['release_year'].min()
# Out:
# 1960

# %% [markdown]
# # Yearly releases

# %%
yearly_releases = df3.groupby('release_year').count()['id']
type(yearly_releases)
yearly_releases[:10].index
# Out:
# Int64Index([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969], dtype='int64', name='release_year')

# %%
plt.bar(yearly_releases[:10].index, yearly_releases[:10])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.bar(yearly_releases[10:20].index, yearly_releases[10:20])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.bar(yearly_releases[20:30].index, yearly_releases[20:30])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.bar(yearly_releases[30:40].index, yearly_releases[30:40])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.bar(yearly_releases[40:50].index, yearly_releases[40:50])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.bar(yearly_releases[50:60].index, yearly_releases[50:60])
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(yearly_releases.index, yearly_releases)
# Out:
# <BarContainer object of 56 artists>

# %% [markdown]
# ## Splitting cells containing list of Genres and creating individual Column for each Genre

# %%
genre = df3['genres'].str.split('|').apply(pd.Series)


genre.head(1)
# Out:
#         0          1                2         3    4
# 0  Action  Adventure  Science Fiction  Thriller  NaN

# %%
genre = df3['genres'].str.split('|').apply(pd.Series)
genre.rename(columns =lambda x: 'genre_' +str(x), inplace=True)
df4 = pd.concat([df3,genre], axis=1, sort=False)

# %%
#genre.rename(columns =lambda x: 'genre_' +str(x), inplace=True)

# %%
genre.head(1)
# Out:
#   genre_0    genre_1          genre_2   genre_3 genre_4
# 0  Action  Adventure  Science Fiction  Thriller     NaN

# %%
df3.head(1)
# Out:
#        id    imdb_id  popularity     budget     revenue  original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
#
#                         homepage         director            tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow  The park is open.  ...
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies  release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...        6/9/15       5562
#
#   vote_average release_year    budget_adj   revenue_adj        profit  \
# 0          6.5         2015  1.379999e+08  1.392446e+09  1.254446e+09
#
#     %profit
# 0  9.090192
#
# [1 rows x 23 columns]

# %%
df4 = pd.concat([df3,genre], axis=1, sort=False)

# %%
df4.head(1)
# Out:
#        id    imdb_id  popularity     budget     revenue  original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
#
#                         homepage         director            tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow  The park is open.  ...
#
#   release_year    budget_adj   revenue_adj        profit   %profit genre_0  \
# 0         2015  1.379999e+08  1.392446e+09  1.254446e+09  9.090192  Action
#
#      genre_1          genre_2   genre_3  genre_4
# 0  Adventure  Science Fiction  Thriller      NaN
#
# [1 rows x 28 columns]

# %%
plt.bar(yearly_releases.index, yearly_releases) 
#df.loc[((df['Value_1'] > 1000) 
     #  |(df['Value_2'] > 15000)), 'High_Value_Ind'] = 'Y'
# Out:
# <BarContainer object of 56 artists>

# %% [markdown]
# # Create New Column Profit Category

# %% [markdown]
# Based upon % Profit is less than zeor
# % Profit <1 but >0
# % Profit >= 1

# %%
df4.loc[(df4['%profit'] > 1), 'profit_category'] = '>1'

# %%
df4.loc[((df4['%profit'] <= 1) & (df4['%profit']  >= 0)), 'profit_category'] = '1<>0'

# %%
df4.loc[(df4['%profit'] < 0), 'profit_category'] = '<0'

# %%
df4.head(1)
# Out:
#        id    imdb_id  popularity     budget     revenue  original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
#
#                         homepage         director            tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow  The park is open.  ...
#
#      budget_adj   revenue_adj        profit   %profit genre_0    genre_1  \
# 0  1.379999e+08  1.392446e+09  1.254446e+09  9.090192  Action  Adventure
#
#            genre_2   genre_3  genre_4  profit_category
# 0  Science Fiction  Thriller      NaN               >1
#
# [1 rows x 29 columns]

# %%
df4.groupby('genre_0').count()['id']

# %%
plt.figure(figsize=(25, 8))
plt.bar(df4.groupby('genre_0').count()['id'].sort_values().index, df4.groupby('genre_0').count()['id'].sort_values() )
# Out:
# <BarContainer object of 19 artists>

# %%
df4[((df4['profit_category'] =='>1') & (df4['release_year']>2010))].groupby('genre_0').count()['id']
# Out:
# genre_0
# Action             81
# Adventure          31
# Animation          22
# Comedy             86
# Crime              17
# Documentary         6
# Drama              99
# Family              8
# Fantasy            10
# History             4
# Horror             33
# Music               3
# Mystery             3
# Romance            11
# Science Fiction    18
# Thriller           31
# War                 5
# Western             1
# Name: id, dtype: int64

# %%
plt.bar(df4.groupby('genre_0').count()['id'].sort_values().index, df4.groupby('genre_0').count()['id'].sort_values() )

# %%
plt.scatter(df4['budget_adj'], df4['%profit'])

# %%
df3['budget_adj'].corr(df3['revenue_adj'])
# Out:
# 0.570466122118637

# %%
plt.scatter(df4['budget_adj'], df4['revenue_adj'])

# %%
df4['popularity'].corr(df4['%profit'])
# Out:
# -0.005448847747649917

# %%
plt.bar(df4.groupby('profit_category').count()['id'].index, df4.groupby('profit_category').count()['id'])
# Out:
# <BarContainer object of 3 artists>

# %%
df4.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj', 'profit', '%profit', 'genre_0', 'genre_1', 'genre_2',
#        'genre_3', 'genre_4', 'profit_category'],
#       dtype='object')

# %%
df4['budget_adj'].corr(df4['%profit'])
# Out:
# -0.017712768790384963

# %% [markdown]
# # Create Separate Columns for

# %%
df4['production_companies'].head(10)
# Out:
# 0    Universal Studios|Amblin Entertainment|Legenda...
# 1    Village Roadshow Pictures|Kennedy Miller Produ...
# 2    Summit Entertainment|Mandeville Films|Red Wago...
# 3            Lucasfilm|Truenorth Productions|Bad Robot
# 4    Universal Pictures|Original Film|Media Rights ...
# 5    Regency Enterprises|Appian Way|CatchPlay|Anony...
# 6              Paramount Pictures|Skydance Productions
# 7    Twentieth Century Fox Film Corporation|Scott F...
# 8        Universal Pictures|Illumination Entertainment
# 9    Walt Disney Pictures|Pixar Animation Studios|W...
# Name: production_companies, dtype: object

# %%
production_companies = df4['production_companies'].str.split('|').apply(pd.Series)

# %%
production_companies.rename(columns = lambda x: 'prod_com_' + str(x), inplace = True)

# %%
#dfx = pd.concat([df_movies,genre], axis=1, sort=False)

# %%
df5 = pd.concat([df4, production_companies], axis=1, sort=False)

# %%
df5.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj', 'profit', '%profit', 'genre_0', 'genre_1', 'genre_2',
#        'genre_3', 'genre_4', 'profit_category', 'prod_com_0', 'prod_com_1',
#        'prod_com_2', 'prod_com_3', 'prod_com_4'],
#       dtype='object')

# %%
df5.groupby('prod_com_0').sum()['profit']
# Out:
# prod_com_0
# 10th Hole Productions               -4.376180e+06
# 120dB Films                          1.334861e+03
# 1492 Pictures                        2.831008e+09
# 1818                                 1.583448e+07
# 20th Century Fox                     2.334270e+09
# 21 Laps Entertainment                4.076061e+06
# 26 Films                            -9.944911e+06
# 2929 Productions                    -3.266558e+07
# 3 Arts Entertainment                 1.934056e+06
# 3311 Productions                     1.838278e+06
# 40 Acres & A Mule Filmworks          2.844122e+06
# A Band Apart                         9.504378e+06
# A Loopy Production LLC              -4.239557e+05
# ABC Motion Pictures                 -1.651657e+07
# ABC Pictures                         5.664116e+06
# ABS-CBN Film Productions            -5.491380e+05
# ARD Degeto Film                      2.366689e+07
# ARP SÃ©lection                      -1.280480e+07
# ...

# %%
sum(df5['profit']) #357,717,350,097.82043
# Out:
# 357717350097.82043

# %%
df5['budget_adj'].sum() #170,530,933,330.10126
# Out:
# 170530933330.10126

# %%
df5['revenue_adj'].sum() #528,248,283,427.92175
# Out:
# 528248283427.92175

# %%
directors = df5.groupby('director').sum()['profit'].sort_values(ascending=False)
directors[directors>0].quantile(.25)
#19,826,811
# Out:
# 19826811.945803918

# %%
plt.boxplot(directors[directors>0])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16159c31198>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16159e073c8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16159c31438>],
#  'medians': [<matplotlib.lines.Line2D at 0x16159e29198>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16159ac2ac8>],
#  'means': []}

# %%
directors[directors>0].quantile(.50)
#80,263,174
# Out:
# 80263174.59562977

# %%
directors[directors>0].quantile(.75)
#304,961,927
# Out:
# 304961927.1186408

# %%
directors[directors>0].quantile(.9)
756,394,580.4347405
# Out:
# 756394580.4347405

# %%
directors[directors>0].quantile(.99)
#2,672,719,591
# Out:
# 2672719591.8524647

# %% [markdown]
# ###### How much money top 10% directors movies have made

# %%
directors[directors>0].quantile(.90)
#2,672,719,591
d1
# Out:
# 756394580.4347405

# %%
directors[directors>0].head(125).sum()
#186,599,596,024
# Out:
# 207309700480.72394

# %% [markdown]
# # Top 10% of directors' movies have grossed 58% of the total profit

# %% [markdown]
# # Conclusion: Director is significant predictor of the movies success.

# %%
207309700480.72394/ 357717350097
# Out:
# 0.5795349328862831

# %%
len(directors[directors>0])
# Out:
# 1252

# %%
100/1252
# Out:
# 0.07987220447284345

# %%
#df5.groupby('director').sum()['profit'].sort_values(ascending=False)

# %% [markdown]
# # Question: Is Genre a significant predictor of movie's success

# %%
plot_genre(dfx, 1960, 2015)

# %%
plot_genre(df5, 1960, 2015)

# %% [markdown]
# ##### 60% the movies 1960 to 2015 produced belong to Drama, Comedy, or Action Genre

# %%
top_genre= df5[((df5['genre_0']=='Drama') | (df5['genre_0']=='Comedy') | (df5['genre_0']=='Action'))]

# %%
top_genre.head()['genre_0']
# Out:
# 0    Action
# 1    Action
# 3    Action
# 4    Action
# 7     Drama
# Name: genre_0, dtype: object

# %%
top_genre['profit'].mean()
# Out:
# 75319307.29141173

# %%
df3['profit'].mean()
# Out:
# 92793086.92550465

# %%
df5[(df5['genre_0']=='Crime')]['profit'].mean()
# Out:
# 66057424.74573644

# %%
df5[(df5['genre_0']=='Horror')]['profit'].mean()
# Out:
# 59308603.50889674

# %%
df5[(df5['genre_0']=='Adventure')]['profit'].mean()
# Out:
# 217998880.96758392

# %%
df5.groupby('genre_0').count()['id'].sort_values(ascending=False)

# %%
genre_profit_means = df5.groupby('genre_0').describe()['profit']

# %%
df5[(df5['genre_0']=='Adventure')]['profit'].mean()
# Out:
# 217998880.96758392

# %%
genre_profit_means['mean']
# Out:
# genre_0
# Action             1.015973e+08
# Adventure          2.179989e+08
# Animation          2.105722e+08
# Comedy             6.954777e+07
# Crime              6.605742e+07
# Documentary        1.870554e+07
# Drama              6.007961e+07
# Family             2.053924e+08
# Fantasy            1.302785e+08
# History            1.181293e+08
# Horror             5.930860e+07
# Music              8.555408e+07
# Mystery            5.078793e+07
# Romance            9.253587e+07
# Science Fiction    1.546632e+08
# TV Movie           5.143802e+07
# Thriller           5.330621e+07
# War                7.647568e+07
# Western            5.391862e+07
# Name: mean, dtype: float64

# %%
plt.figure(figsize=(24,8))
plt.bar(genre_profit_means['mean'].sort_values(ascending=False).index, genre_profit_means["mean"].sort_values(ascending=False))
plt.title('Average Profit of each Genre', fontsize=40)
plt.axhline(92793086.92550465, color='red', label='adsf')

# %%
df6["profit"].mean()
# Out:
# 92793086.92550465

# %%
genre_budget_means = df5.groupby('genre_0').describe()['budget_adj']

# %%
plt.figure(figsize=(25,8))
plt.bar(genre_budget_means['mean'].sort_values(ascending=False).index, genre_budget_means["mean"].sort_values(ascending=False))
plt.title('Average Budget of the Genre', fontsize=40)
# Out:
# Text(0.5, 1.0, 'Average Budget of the Genre')

# %%
df5['budget_adj'].corr(df5['profit'])
# Out:
# 0.4043700847990902

# %%
df5['budget_adj'].corr(df5['revenue_adj'])
# Out:
# 0.570466122118637

# %%
plt.scatter(df5['budget_adj'],df5['profit'])

# %%
df5.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj', 'profit', '%profit', 'genre_0', 'genre_1', 'genre_2',
#        'genre_3', 'genre_4', 'profit_category', 'prod_com_0', 'prod_com_1',
#        'prod_com_2', 'prod_com_3', 'prod_com_4'],
#       dtype='object')

# %%
key_words = df5['keywords'].str.split('|').apply (pd.Series)
key_words.rename(columns=lambda x: 'k_w_'+str(x), inplace=True)
df6 = pd.concat([df5,key_words], axis=1, sort=False)

# %%
df6.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj', 'profit', '%profit', 'genre_0', 'genre_1', 'genre_2',
#        'genre_3', 'genre_4', 'profit_category', 'prod_com_0', 'prod_com_1',
#        'prod_com_2', 'prod_com_3', 'prod_com_4', 'k_w_0', 'k_w_1', 'k_w_2',
#        'k_w_3', 'k_w_4'],
#       dtype='object')

# %%
cast = df5['cast'].str.split('|').apply (pd.Series)
cast.rename(columns=lambda x: 'cast'+str(x), inplace=True)
df6 = pd.concat([df6,cast], axis=1, sort=False)
df6.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj', 'profit', '%profit', 'genre_0', 'genre_1', 'genre_2',
#        'genre_3', 'genre_4', 'profit_category', 'prod_com_0', 'prod_com_1',
#        'prod_com_2', 'prod_com_3', 'prod_com_4', 'k_w_0', 'k_w_1', 'k_w_2',
#        'k_w_3', 'k_w_4', 'cast0', 'cast1', 'cast2', 'cast3', 'cast4'],
#       dtype='object')

# %% [markdown]
# # Cast impact on Profitability

# %%
df6.groupby('cast0')['profit'].sum().sort_values(ascending=False).head(71).sum()
# 229,246,958,934
# Out:
# 198259387991.34006

# %%
df6.cast0.nunique()
# Out:
# 1427

# %%
1427*.05
# Out:
# 71.35000000000001

# %%
198259387991.34006 /df6['profit'].sum()
# Out:
# 0.5542347552812984

# %% [markdown]
# ## Top 5% actors' movies have grossed more than 55% of the all time movie profit
# Therefore we can conclude that Cast impacts prositively the overall profitability of the movie

# %%
1427*.2
# Out:
# 285.40000000000003

# %%
df6.groupby('cast0')['profit'].sum().sort_values(ascending=False).head(285).sum() / df6['profit'].sum()
# Out:
# 0.8807005272136076

# %%
#average actor's movie profit
df6['profit'].sum()/ 1427
# Out:
# 250677890.74829742

# %%
plt.figure(figsize=(16,8))
plt.bar(df6.groupby('cast0')['profit'].sum().sort_values(ascending=False).head(10).index, df6.groupby('cast0')['profit'].sum().sort_values(ascending=False).head(10) )
plt.axhline(250677890,  label="something", color='red', linestyle='dashed')
plt.show()

# %% [markdown]
# #### Top 20% actors's  movies have grossed 88% of the overall profit

# %% [markdown]
# # Key Words impact on movie's pofitiability

# %%
df6.groupby('k_w_0')['profit'].sum().sort_values(ascending=False).head(124).sum()
# Out:
# 227140316381.06662

# %%
df6.groupby('k_w_0')['profit'].sum().sort_values(ascending=False).head(124).sum() /df6['profit'].sum()
# Out:
# 0.63497148326452

# %% [markdown]
# ## Top 10% of the Keywords containing movies have share of 63% of the profit

# %%
df6.groupby('k_w_0')['profit'].sum().sort_values(ascending=False).head(124).sum() /df6['profit'].sum()
# Out:
# 0.63497148326452

# %%
df6['profit'].sum() /1240
# Out:
# 288481733.9498552

# %%
plt.figure(figsize=(16,8))
plt.bar(df6.groupby('k_w_0')['profit'].sum().sort_values(ascending=False).head(10).index, df6.groupby('k_w_0')['profit'].sum().sort_values(ascending=False).head(10) )
plt.axhline((df6['profit'].sum()/1240),  label="something", color='red', linestyle='dashed')
plt.show()

# %% [markdown]
# ## Top 20% of the Keywords containing movies have share of 81% of the profit

# %% [markdown]
# # Ratings impact on profitability

# %%
df6.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj', 'profit', '%profit', 'genre_0', 'genre_1', 'genre_2',
#        'genre_3', 'genre_4', 'profit_category', 'prod_com_0', 'prod_com_1',
#        'prod_com_2', 'prod_com_3', 'prod_com_4', 'k_w_0', 'k_w_1', 'k_w_2',
#        'k_w_3', 'k_w_4', 'cast0', 'cast1', 'cast2', 'cast3', 'cast4'],
#       dtype='object')

# %%
df6['vote_average'].corr(df6['profit'])
# Out:
# 0.2887952397883306

# %%
df6['popularity'].corr(df6['profit'])
# Out:
# 0.5168959880485963

# %% [markdown]
# # Popularity has reasonable correlation with profit

# %%
df6['vote_count'].corr(df6['profit'])
# Out:
# 0.6140897440676105

# %% [markdown]
# ## Vote Count has strong correlation with Profitability of the movie - strangely ;)

# %% [markdown]
# # Production Company Impact on movie's profitability

# %%
#df6.groupby("prod_com_0")['profit'].sum().sort_values(ascending=False)
#894 total production companies

# %%
#Average profit per production company
df6['profit'].sum() / 894
# Out:
# 400131264.09152174

# %% [markdown]
# # Top 10% of production companies account for 91% of overall movie profit

# %%
plt.figure(figsize=(16,8))
plt.bar(df6.groupby('prod_com_0')['profit'].sum().sort_values(ascending=False).head(8).index, df6.groupby('prod_com_0')['profit'].sum().sort_values(ascending=False).head(8) )
plt.axhline((df6['profit'].sum()/894),  label="something", color='red', linestyle='dashed')
plt.show()

# %%
df6.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj', 'profit', '%profit', 'genre_0', 'genre_1', 'genre_2',
#        'genre_3', 'genre_4', 'profit_category', 'prod_com_0', 'prod_com_1',
#        'prod_com_2', 'prod_com_3', 'prod_com_4', 'k_w_0', 'k_w_1', 'k_w_2',
#        'k_w_3', 'k_w_4', 'cast0', 'cast1', 'cast2', 'cast3', 'cast4'],
#       dtype='object')
